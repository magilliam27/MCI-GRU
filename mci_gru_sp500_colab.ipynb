# %% [markdown]
# # MCI-GRU on S&P 500 (Colab)
#
# This notebook assumes you will upload:
# - `mci_gru_sp500.py`
# - your tickers CSV (e.g., `tickers.csv`)
#
# No model code is duplicated here; we simply install dependencies and run the pipeline.

# %%
# Install dependencies
# !pip -q install yfinance pandas numpy torch torch-geometric scikit-learn matplotlib tqdm

# %%
# (Optional) Upload files if not already present
# from google.colab import files
# uploaded = files.upload()

# %%
# Run the pipeline from the uploaded script
import mci_gru_sp500 as mci

# Update to the exact filename you upload to Colab
mci.TICKER_CSV_PATH = "tickers.csv"

# Execute
model, test_returns, metrics = mci.main(mci.TICKER_CSV_PATH)
